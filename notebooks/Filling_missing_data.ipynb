# %%
"""
Fra andre key kommer data. 
1990 - 2023
Ikke 2013
K11 er CO2
K12 er CH4
"""
your_data = {'columns': [{'code': 'UtslpEnergivare', 'text': 'energiprodukt', 'type': 'd'}, {'code': 'UtslpKomp', 'text': 'komponent', 'type': 'd'}, {'code': 'Tid', 'text': 'år', 'type': 't'}, {'code': 'UtslippCO2ekvival', 'text': 'Utslipp til luft (1 000 tonn CO2-ekvivalenter, AR5)', 'type': 'c'}, {'code': 'Utslipp', 'text': 'Utslipp til luft (CO2 i 1 000 tonn, CH4 og N2O i tonn, HFK, PFK og SF6 i kg)', 'type': 'c'}], 'comments': [], 'data': [{'key': ['VT0', 'A10', '1990'], 'values': ['51348', '.']}, {'key': ['VT0', 'A10', '1991'], 'values': ['48987', '.']}, {'key': ['VT0', 'A10', '1992'], 'values': ['47450', '.']}, {'key': ['VT0', 'A10', '1993'], 'values': ['49379', '.']}, {'key': ['VT0', 'A10', '1994'], 'values': ['51331', '.']}, {'key': ['VT0', 'A10', '1995'], 'values': ['51741', '.']}, {'key': ['VT0', 'A10', '1996'], 'values': ['54642', '.']}, {'key': ['VT0', 'A10', '1997'], 'values': ['54619', '.']}, {'key': ['VT0', 'A10', '1998'], 'values': ['54694', '.']}, {'key': ['VT0', 'A10', '1999'], 'values': ['55698', '.']}, {'key': ['VT0', 'A10', '2000'], 'values': ['55092', '.']}, {'key': ['VT0', 'A10', '2001'], 'values': ['56344', '.']}, {'key': ['VT0', 'A10', '2002'], 'values': ['55034', '.']}, {'key': ['VT0', 'A10', '2003'], 'values': ['55655', '.']}, {'key': ['VT0', 'A10', '2004'], 'values': ['56028', '.']}, {'key': ['VT0', 'A10', '2005'], 'values': ['54897', '.']}, {'key': ['VT0', 'A10', '2006'], 'values': ['54870', '.']}, {'key': ['VT0', 'A10', '2007'], 'values': ['56548', '.']}, {'key': ['VT0', 'A10', '2008'], 'values': ['55026', '.']}, {'key': ['VT0', 'A10', '2009'], 'values': ['52541', '.']}, {'key': ['VT0', 'A10', '2010'], 'values': ['54855', '.']}, {'key': ['VT0', 'A10', '2011'], 'values': ['53848', '.']}, {'key': ['VT0', 'A10', '2012'], 'values': ['53258', '.']}, {'key': ['VT0', 'A10', '2014'], 'values': ['53878', '.']}, {'key': ['VT0', 'A10', '2015'], 'values': ['54417', '.']}, {'key': ['VT0', 'A10', '2016'], 'values': ['53533', '.']}, {'key': ['VT0', 'A10', '2017'], 'values': ['52838', '.']}, {'key': ['VT0', 'A10', '2018'], 'values': ['52991', '.']}, {'key': ['VT0', 'A10', '2019'], 'values': ['51223', '.']}, {'key': ['VT0', 'A10', '2020'], 'values': ['49499', '.']}, {'key': ['VT0', 'A10', '2021'], 'values': ['49325', '.']}, {'key': ['VT0', 'A10', '2022'], 'values': ['48973', '.']}, {'key': ['VT0', 'A10', '2023'], 'values': ['46654', '.']}, {'key': ['VT0', 'K11', '1990'], 'values': ['35009', '35009']}, {'key': ['VT0', 'K11', '1991'], 'values': ['33466', '33466']}, {'key': ['VT0', 'K11', '1992'], 'values': ['34402', '34402']}, {'key': ['VT0', 'K11', '1993'], 'values': ['35948', '35948']}, {'key': ['VT0', 'K11', '1994'], 'values': ['37863', '37863']}, {'key': ['VT0', 'K11', '1995'], 'values': ['38469', '38469']}, {'key': ['VT0', 'K11', '1996'], 'values': ['41540', '41540']}, {'key': ['VT0', 'K11', '1997'], 'values': ['41644', '41644']}, {'key': ['VT0', 'K11', '1998'], 'values': ['41838', '41838']}, {'key': ['VT0', 'K11', '1999'], 'values': ['42609', '42609']}, {'key': ['VT0', 'K11', '2000'], 'values': ['42131', '42131']}, {'key': ['VT0', 'K11', '2001'], 'values': ['43519', '43519']}, {'key': ['VT0', 'K11', '2002'], 'values': ['42571', '42571']}, {'key': ['VT0', 'K11', '2003'], 'values': ['43919', '43919']}, {'key': ['VT0', 'K11', '2004'], 'values': ['44257', '44257']}, {'key': ['VT0', 'K11', '2005'], 'values': ['43279', '43279']}, {'key': ['VT0', 'K11', '2006'], 'values': ['43859', '43859']}, {'key': ['VT0', 'K11', '2007'], 'values': ['45605', '45605']}, {'key': ['VT0', 'K11', '2008'], 'values': ['44692', '44692']}, {'key': ['VT0', 'K11', '2009'], 'values': ['43098', '43098']}, {'key': ['VT0', 'K11', '2010'], 'values': ['45659', '45659']}, {'key': ['VT0', 'K11', '2011'], 'values': ['44775', '44775']}, {'key': ['VT0', 'K11', '2012'], 'values': ['44258', '44258']}, {'key': ['VT0', 'K11', '2014'], 'values': ['44975', '44975']}, {'key': ['VT0', 'K11', '2015'], 'values': ['45523', '45523']}, {'key': ['VT0', 'K11', '2016'], 'values': ['44708', '44708']}, {'key': ['VT0', 'K11', '2017'], 'values': ['44197', '44197']}, {'key': ['VT0', 'K11', '2018'], 'values': ['44472', '44472']}, {'key': ['VT0', 'K11', '2019'], 'values': ['42866', '42866']}, {'key': ['VT0', 'K11', '2020'], 'values': ['41275', '41275']}, {'key': ['VT0', 'K11', '2021'], 'values': ['41058', '41058']}, {'key': ['VT0', 'K11', '2022'], 'values': ['40833', '40833']}, {'key': ['VT0', 'K11', '2023'], 'values': ['38869', '38869']}, {'key': ['VT0', 'K12', '1990'], 'values': ['6843', '244407']}, {'key': ['VT0', 'K12', '1991'], 'values': ['6671', '238241']}, {'key': ['VT0', 'K12', '1992'], 'values': ['6763', '241541']}, {'key': ['VT0', 'K12', '1993'], 'values': ['6901', '246471']}, {'key': ['VT0', 'K12', '1994'], 'values': ['7007', '250263']}, {'key': ['VT0', 'K12', '1995'], 'values': ['7027', '250974']}, {'key': ['VT0', 'K12', '1996'], 'values': ['7025', '250905']}, {'key': ['VT0', 'K12', '1997'], 'values': ['7040', '251419']}, {'key': ['VT0', 'K12', '1998'], 'values': ['6790', '242499']}, {'key': ['VT0', 'K12', '1999'], 'values': ['6752', '241136']}, {'key': ['VT0', 'K12', '2000'], 'values': ['6759', '241380']}, {'key': ['VT0', 'K12', '2001'], 'values': ['6747', '240966']}, {'key': ['VT0', 'K12', '2002'], 'values': ['6559', '234267']}, {'key': ['VT0', 'K12', '2003'], 'values': ['6513', '232604']}, {'key': ['VT0', 'K12', '2004'], 'values': ['6388', '228158']}, {'key': ['VT0', 'K12', '2005'], 'values': ['6167', '220234']}, {'key': ['VT0', 'K12', '2006'], 'values': ['6008', '214577']}, {'key': ['VT0', 'K12', '2007'], 'values': ['6104', '218013']}, {'key': ['VT0', 'K12', '2008'], 'values': ['5904', '210872']}, {'key': ['VT0', 'K12', '2009'], 'values': ['5899', '210692']}, {'key': ['VT0', 'K12', '2010'], 'values': ['5856', '209133']}, {'key': ['VT0', 'K12', '2011'], 'values': ['5639', '201388']}, {'key': ['VT0', 'K12', '2012'], 'values': ['5587', '199545']}, {'key': ['VT0', 'K12', '2014'], 'values': ['5464', '195144']}, {'key': ['VT0', 'K12', '2015'], 'values': ['5458', '194926']}, {'key': ['VT0', 'K12', '2016'], 'values': ['5425', '193740']}, {'key': ['VT0', 'K12', '2017'], 'values': ['5340', '190709']}, {'key': ['VT0', 'K12', '2018'], 'values': ['5245', '187335']}, {'key': ['VT0', 'K12', '2019'], 'values': ['5025', '179451']}, {'key': ['VT0', 'K12', '2020'], 'values': ['5011', '178976']}, {'key': ['VT0', 'K12', '2021'], 'values': ['5006', '178782']}, {'key': ['VT0', 'K12', '2022'], 'values': ['4972', '177567']}, {'key': ['VT0', 'K12', '2023'], 'values': ['4796', '171274']}], 'metadata': [{'infofile': 'None', 'updated': '2024-11-06T07:00:00Z', 'label': '13931: Klimagasser AR5, etter energiprodukt, komponent, år og statistikkvariabel', 'source': 'Statistisk sentralbyrå'}]}



import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

def fill_missing_years(data, component, column='UtslippCO2ekvival'):
    # Trekker ut relevant data
    records = []
    for entry in data['data']:
        key = entry['key']
        values = entry['values']
        if key[1] == component:
            year = int(key[2])
            try:
                value = float(values[1])  # Bruker første verdi
                records.append((year, value))
            except ValueError:
                records.append((year, np.nan))  # Setter manglende verdier til NaN
    
    # Konverter til DataFrame
    df = pd.DataFrame(records, columns=['Year', 'Value']).sort_values(by='Year')
    
    # Finn manglende år
    all_years = np.arange(df['Year'].min(), df['Year'].max() + 1)
    df = df.set_index('Year').reindex(all_years).reset_index()
    
    # Regresjon for å fylle ut manglende verdier
    known_data = df.dropna()
    missing_data = df[df['Value'].isna()]
    
    if not missing_data.empty:
        model = LinearRegression()
        model.fit(known_data[['Year']], known_data['Value'])
        df.loc[df['Value'].isna(), 'Value'] = model.predict(missing_data[['Year']])
    
    return df
filled_data = fill_missing_years(your_data, 'K12')
print(filled_data)
# Out:
#     Year          Value
# 0   1990  244407.000000
# 1   1991  238241.000000
# 2   1992  241541.000000
# 3   1993  246471.000000
# 4   1994  250263.000000
# 5   1995  250974.000000
# 6   1996  250905.000000
# 7   1997  251419.000000
# 8   1998  242499.000000
# 9   1999  241136.000000
# 10  2000  241380.000000
# 11  2001  240966.000000
# 12  2002  234267.000000
# 13  2003  232604.000000
# 14  2004  228158.000000
# 15  2005  220234.000000
# 16  2006  214577.000000
# 17  2007  218013.000000
# 18  2008  210872.000000
# 19  2009  210692.000000
# 20  2010  209133.000000
# 21  2011  201388.000000
# 22  2012  199545.000000
# 23  2013  200222.246011
# 24  2014  195144.000000
# 25  2015  194926.000000
# 26  2016  193740.000000
# 27  2017  190709.000000
# 28  2018  187335.000000
# 29  2019  179451.000000
# 30  2020  178976.000000
# 31  2021  178782.000000
# 32  2022  177567.000000
# 33  2023  171274.000000
